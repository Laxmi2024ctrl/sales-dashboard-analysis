# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Sales_Dataset_2024.csv")
df.head(24)
# Out:
#                    Date Region     Product Salesperson  Units_Sold  \
# 0   2024-04-12 00:00:00  North  Smartwatch      Hannah        15.0
# 1   2024-12-14 00:00:00  North     Monitor         Eva         5.0
# 2   2024-09-27 00:00:00  North      Mobile         Bob        11.0
# 3   2024-04-16 00:00:00   West     Monitor     Charlie        18.0
# 4   2024-03-12 00:00:00   West  Headphones         Eva        13.0
# 5   2024-07-07 00:00:00   West     Monitor     Charlie        11.0
# 6   2024-01-21 00:00:00   West  Headphones     Charlie        14.0
# 7   2024-04-12 00:00:00   East      Camera       Grace        18.0
# 8   2024-05-01 00:00:00   East      Laptop       Grace        19.0
# 9   2024-08-02 00:00:00  South     Printer      Hannah        15.0
# 10  2024-11-26 00:00:00   West  Headphones         NaN         9.0
# 11  2024-03-28 00:00:00   East      Laptop         Eva         8.0
# 12  2024-04-09 00:00:00  North  Smartwatch       Alice         1.0
# ...
